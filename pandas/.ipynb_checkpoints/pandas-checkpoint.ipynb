# %% [markdown]
# # Pandas Practical Guide

# %%
import pandas as pd

# %%
# Importing Data
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#To obtain list of columns
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Get the dimensions of DataFrame (rows and columns)
n_rows, n_cols = titanic.shape
print(n_rows,n_cols)
# Out:
# 891 12

# %% [markdown]
# ## Parts of a DataFrame
# In the pandas library, there are two primary data structures:
# * DataFrame-
#   It is a 2-D labeled data structure. It consists of rows and columns and can hold different types of data.
# * Series-
#   A Series is a 1-dimensional labeled array.
# Each column in a DataFrame is essentially a Series.
#
# A DataFrame is a collection of multiple Series objects aligned along the same index (rows).

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(titanic['Name'])
# Out:
# pandas.core.series.Series

# %%
type(titanic[['Name','Age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Basics of selecting/renaming/reindexing Rows and Columns

# %%
# ename the columns of a DataFrame
titanic.rename(columns={'Cabin': 'Room'}, inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Drop columns from DataFrame
titanic_drop = titanic.drop(columns=['SibSp'])
titanic_drop.shape
# Out:
# (891, 11)

# %%
# By default, each row in a DataFrame is labelled using integers 0 to (n-1). To acess say the 5th:
titanic.loc[4]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Room                                NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
# We can use Name to label the rows:
titanic_re = titanic.set_index('Name')
titanic_re
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
#Now since row index is Name to get the 5th row we can use iloc:
titanic_re.iloc[4]
# Out:
# PassengerId         5
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Room              NaN
# Embarked            S
# Name: Allen, Mr. William Henry, dtype: object

# %%
#To see first two rows
titanic.loc[0:1]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Room Embarked
# 0      0  A/5 21171   7.2500  NaN        S
# 1      0   PC 17599  71.2833  C85        C

# %%
#to see first two columns
titanic.iloc[:, :4]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# ...

# %%
#Print first two columns
#Since the columns are also index using names like: Passengerid,Survived,Pclass etc we need to use iloc
titanic.iloc[:,0:4]
# : means all rows
# 0:4 means first 4 columns
# [2,3] will give columns with labels 2 and 3
titanic.iloc[:,[2,3]]
# Out:
#      Pclass                                               Name
# 0         3                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         3                           Allen, Mr. William Henry
# ..      ...                                                ...
# 886       2                              Montvila, Rev. Juozas
# 887       1                       Graham, Miss. Margaret Edith
# 888       3           Johnston, Miss. Catherine Helen "Carrie"
# 889       1                              Behr, Mr. Karl Howell
# 890       3                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
#extract just 4th and 5th row as well as 1,2,3 columns
titanic.iloc[[3,4],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 4            5         0       3

# %% [markdown]
# ## Filtering

# %%
#extract rows with Age more than 30
titanic[titanic['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Extract data with Age >30 and Fare less than 50
titanic[(titanic['Age']>30) & (titanic['Fare']<50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 872          873         0       1
# 873          874         0       3
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    male  35.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Extract data with pclass 1 and 3
titanic[titanic['Pclass'].isin([1,3])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Drop index
titanic[(titanic['Age']==40)].reset_index(drop=True)
# Out:
#     PassengerId  Survived  Pclass  \
# 0            31         0       1
# 1            41         0       3
# 2           162         1       2
# 3           189         0       3
# 4           210         1       1
# 5           264         0       1
# 6           320         1       1
# 7           347         1       2
# 8           361         0       3
# 9           562         0       3
# 10          610         1       1
# 11          662         0       3
# 12          671         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                            Uruchurtu, Don. Manuel E    male  40.0      0
# 1      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 2   Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0      0
# 3                                    Bourke, Mr. John    male  40.0      1
# 4                                    Blank, Mr. Henry    male  40.0      0
# ...

# %% [markdown]
# ## Sorting

# %%
titanic.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 438          439         0       1                   Fortune, Mr. Mark
# 88            89         1       1          Fortune, Miss. Mabel Helen
# ..           ...       ...     ...                                 ...
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# 271          272         1       3        Tornquist, Mr. William Henry
# 263          264         0       1               Harrison, Mr. William
# 466          467         0       2               Campbell, Mr. William
# 806          807         0       1              Andrews, Mr. Thomas Jr
#
#         Sex   Age  SibSp  Parch    Ticket      Fare         Room Embarked
# ...

# %% [markdown]
# ## Filtering with Strings

# %%
#lower 
titanic['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic['Name'] = titanic['Name'].str.lower()
#Check if any name contains reverence
titanic[titanic['Name'].str.contains("rev.")]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 149          150         0       2  byles, rev. thomas roussel davids  male
# 150          151         0       2         bateman, rev. robert james  male
# 249          250         0       2      carter, rev. ernest courtenay  male
# 305          306         1       1     allison, master. hudson trevor  male
# 626          627         0       2     kirkland, rev. charles leonard  male
# 848          849         0       2                  harper, rev. john  male
# 886          887         0       2              montvila, rev. juozas  male
#
#        Age  SibSp  Parch       Ticket     Fare     Room Embarked
# 149  42.00      0      0       244310   13.000      NaN        S
# 150  51.00      0      0  S.O.P. 1166   12.525      NaN        S
# 249  54.00      1      0       244252   26.000      NaN        S
# 305   0.92      1      2       113781  151.550  C22 C26        S
# ...

# %% [markdown]
# ## Aggregations

# %%
# Number of distinct values in a column
titanic['Age'].nunique()
# Out:
# 88

# %%
# describe (basic statistics for each column)
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
#value_counts (Count number of rows with each unique value of variable)
#(30 peaople with age 24, 27 with age 22, etc..)
titanic['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ## Plotting

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
titanic['Age'].plot()
# Out:
# <Axes: >

# %%
titanic[['Age','Survived']].plot(x='Age',y='Survived',kind='scatter',figsize=(20,10))
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
#histograms (Helps find outlier)
titanic.hist(figsize=(20,10),bins=100)
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Loading Space-Separated .data Files

# %%
Auto = pd.read_csv('Auto.data', sep=r"\s+") # sep as regex (whitespace or tab)
# or Auto = pd.read_csv('Auto.data', delim_whitespace=True) 
Auto.shape
# Out:
# (397, 9)

# %%
Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ## Handeling Missing entries

# %%
# Remove rows with ? values
Auto = pd.read_csv('Auto.data',sep=r'\s+',na_values='?') # Replaces ? with NaN
Auto_re = Auto.dropna() # Drop rows with any column having NA or null data.
Auto_re.shape
# Out:
# (392, 9)

# %%
# Replace all NA/null data with value.
Auto = Auto.fillna('@')
Auto.iloc[32]
# Out:
# mpg                   25.0
# cylinders                4
# displacement          98.0
# horsepower               @
# weight              2046.0
# acceleration          19.0
# year                    71
# origin                   1
# name            ford pinto
# Name: 32, dtype: object

# %% [markdown]
# ## Using Query
# query() allows Boolean expressions for filtering rows

# %%
titanic.query('Age > 20 and Fare > 50 and Name.str.contains("mr.")')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 34            35         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 838          839         1       3
# 856          857         1       1
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 6                              mccarthy, mr. timothy j    male  54.0      0
# 34                             meyer, mr. edgar joseph    male  28.0      1
# 35                      holverson, mr. alexander oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Creating a dataframe
# Add 2 new members to titanic

# %%
#Using dictionary (Most common way)
titanic = pd.read_csv('titanic.csv')
d = {'PassengerId':['892','893'], 'Survived':[0,1], 'Pclass':[3,1], 'Name':['Jack','Rose'], 'Sex':['male','female']}
df1 = pd.DataFrame(d)
df1.shape
# Out:
# (2, 5)

# %%
# Add more columns to df1
df1['Age'] = [22,19]
df1['SibSp'] = [0,1]
df1['Parch'] = [0,0]
df1['Ticket'] = ['A/5 21171', 'PC 17599']
df1['Fare'] = [7.25, 71.2833]
df1['Cabin']= [None, 'C85']
df1['Embarked']= ['S', 'C']
df1.shape
# Out:
# (2, 12)

# %%
titanic = pd.concat([titanic,df1])

# %%
titanic.reset_index()
# Out:
#      index PassengerId  Survived  Pclass  \
# 0        0           1         0       3
# 1        1           2         1       1
# 2        2           3         1       3
# 3        3           4         1       1
# 4        4           5         0       3
# ..     ...         ...       ...     ...
# 888    888         889         0       3
# 889    889         890         1       1
# 890    890         891         0       3
# 891      0         892         0       3
# 892      1         893         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## Storing values as numpy

# %%
x = titanic['Age'].to_numpy() # x = titanic['Age'].values
